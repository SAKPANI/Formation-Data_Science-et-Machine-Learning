# %%
import pandas as pd

# %%
df= pd.read_excel("data.xlsx")
df.head()
# Out:
#                        Dataset Name Domain  \
# 0  Common Voice (African Languages)    NLP
# 1     KenSwQuAD: Swahili QA Dataset    NLP
# 2                           FLORES+    NLP
# 3       Leyu Amharic Speech Dataset    NLP
# 4                  WAXAL collection    NLP
#
#                                               Source      Country  \
# 0                                            Mozilla  Africa-wide
# 1                           Barack W. Wanjawa et al.        Kenya
# 2                                  Facebook AI /Meta  Africa-wide
# 3                                            Leyu.ai     Ethiopia
# 4  Makerere University, The University of Ghana, ...  Africa-wide
#
#      Data Type                            License  \
# 0        Audio  Open Access (CC0 – Public Domain)
# 1         Text                 Public (Via arXiv)
# 2         Text         Open Access (CC BY-SA 4.0)
# 3  Audio, Text            Open Access (CC BY 4.0)
# ...

# %%
df.shape
# Out:
# (296, 10)

# %%
df.isnull().sum()
# Out:
# Dataset Name         0
# Domain               0
# Source               0
# Country              0
# Data Type            1
# License             33
# Link                 9
# Use Cases            2
# Last Updated         1
# Challenges/Notes     4
# dtype: int64

# %%
data = pd.read_csv("../sang.csv")

# %%
data.head()
# Out:
#      donor_id              name                          email    password  \
# 0  1b8b4c828a      Norma Fisher            ysullivan@yahoo.com  P5hX6Syg*A
# 1  a6a3f7fe55     Eugene Bowman       hramos@brown-sellers.com  b6Wq6Cqz@5
# 2  cee6478144  Sheri Bolton DDS          jasmine85@hotmail.com  $9RB51m#s7
# 3  5986bc55f9        Kelly Boyd  pattylawrence@riley-hayes.com  @5Tdg(4kCm
# 4  93246afe6c     Taylor Guzman       martinezjacob@wilson.com  x!)9Ag@J*7
#
#   contact_number       city blood_group availability  \
# 0  +61 461706749     Hobart          A+           No
# 1  +61 450709944     Darwin         AB-          Yes
# 2  +61 428756361  Melbourne         AB+          Yes
# 3  +61 454318320     Darwin          A-           No
# 4  +61 484158472     Darwin          O-           No
#
#    months_since_first_donation  number_of_donation  pints_donated  created_at
# 0                           65                  31             62  2017-03-17
# ...

# %%
data.isnull().sum()
# Out:
# donor_id                       0
# name                           0
# email                          0
# password                       0
# contact_number                 0
# city                           0
# blood_group                    0
# availability                   0
# months_since_first_donation    0
# number_of_donation             0
# pints_donated                  0
# created_at                     0
# dtype: int64

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
donne = pd.read_csv("")
