# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from sklearn.neighbors import KNeighborsClassifer
#       6 from sklearn.linear_model import LinearRegression
#       7 from sklearn.model_selection import train_testg_split
#
# ImportError: cannot import name 'KNeighborsClassifer' from 'sklearn.neighbors' (C:\Users\dc\anacondau\Lib\site-packages\sklearn\neighbors\__init__.py)

# %%
##Classification est  un  model qui est utiliser pour entrainer des categories de donnes

# %% [markdown]
# # 1-) Classification
