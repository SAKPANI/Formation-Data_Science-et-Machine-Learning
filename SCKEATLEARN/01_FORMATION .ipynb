# %% [markdown]
# ## Apprenstissage superviser (avec SCKIT LEARN)

# %% [markdown]
# <!-- <<Le machine learning c'est l'art de donner a une machine la capacite d'appredre, sans programmer de facon explicite>> Arthur Samuel -->

# %%
# Il existe 03 techniqyue de devellopenement  de modele
